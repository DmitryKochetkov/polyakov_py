# %% [markdown]
# # Задания 19-21 (Теория игр)

# %% [markdown]
# ## №1

# %% [markdown]
# За один ход игрок может добавить в одну из куч (по своему выбору) один камень или увеличить количество камней в куче в два раза. Игра завершается в тот момент, когда суммарное количество камней в кучах становится не менее 75. Победителем считается игрок, сделавший последний ход, т.е. первым получивший такую позицию, при которой в кучах будет 75 или больше камней. В начальный момент в первой куче было 8 камней, во второй куче – $S$ камней; $1 ≤ S ≤ 66$.
#
# **Задание 19.**
#
# Известно, что Ваня выиграл своим первым ходом после неудачного первого хода Пети. Укажите минимальное значение $S$, когда такая ситуация возможна.
#
# **Задание 20.**
#
# Найдите минимальное значение $S$, при котором у Пети есть выигрышная стратегия, причём одновременно выполняются два условия:
#
# − Петя не может выиграть за один ход;
#
# − Петя может выиграть своим вторым ходом независимо от того, как будет ходить Ваня.
#
# **Задание 21**
#
# Найдите два значения $S$, при которых одновременно выполняются два условия:
#
# – у Вани есть выигрышная стратегия, позволяющая ему выиграть первым или вторым ходом при любой игре Пети;
#
# – у Вани нет стратегии, которая позволит ему гарантированно выиграть первым ходом.
# Найденные значения запишите в ответе в порядке возрастания.

# %% [markdown]
# **Аналитическое решение.**
#
# $$
# \left[
# \begin{gathered}
# 8+S \cdot 2 \ge 75 \\
# 8+S
# \end{gathered}
# \right.
# $$

# %% [markdown]
# ### 1.19

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+1, b), (a, b+1), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 75:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if any(game(m) == 'P1' for m in moves(h)):
        return 'V1'

for s in range(1, 66+1, 1):
    print('S = ' + str(s) + ': ' + str(game((8, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: None
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: None
# S = 15: None
# S = 16: None
# S = 17: V1
# S = 18: V1
# S = 19: V1
# S = 20: V1
# S = 21: V1
# S = 22: V1
# S = 23: V1
# S = 24: V1
# S = 25: V1
# S = 26: V1
# S = 27: V1
# S = 28: V1
# S = 29: V1
# S = 30: V1
# S = 31: V1
# S = 32: V1
# S = 33: V1
# S = 34: P1
# S = 35: P1
# S = 36: P1
# S = 37: P1
# S = 38: P1
# S = 39: P1
# S = 40: P1
# S = 41: P1
# S = 42: P1
# S = 43: P1
# S = 44: P1
# S = 45: P1
# S = 46: P1
# S = 47: P1
# S = 48: P1
# S = 49: P1
# S = 50: P1
# S = 51: P1
# S = 52: P1
# S = 53: P1
# S = 54: P1
# S = 55: P1
# S = 56: P1
# S = 57: P1
# S = 58: P1
# S = 59: P1
# S = 60: P1
# S = 61: P1
# S = 62: P1
# S = 63: P1
# S = 64: P1
# S = 65: P1
# S = 66: P1

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+1, b), (a, b+1), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 75:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'

for s in range(1, 66+1, 1):
    print('S = ' + str(s) + ': ' + str(game((8, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: None
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: None
# S = 15: None
# S = 16: None
# S = 17: None
# S = 18: None
# S = 19: None
# S = 20: None
# S = 21: None
# S = 22: None
# S = 23: None
# S = 24: None
# S = 25: None
# S = 26: None
# S = 27: None
# S = 28: None
# S = 29: P2
# S = 30: None
# S = 31: None
# S = 32: P2
# S = 33: V1
# S = 34: P1
# S = 35: P1
# S = 36: P1
# S = 37: P1
# S = 38: P1
# S = 39: P1
# S = 40: P1
# S = 41: P1
# S = 42: P1
# S = 43: P1
# S = 44: P1
# S = 45: P1
# S = 46: P1
# S = 47: P1
# S = 48: P1
# S = 49: P1
# S = 50: P1
# S = 51: P1
# S = 52: P1
# S = 53: P1
# S = 54: P1
# S = 55: P1
# S = 56: P1
# S = 57: P1
# S = 58: P1
# S = 59: P1
# S = 60: P1
# S = 61: P1
# S = 62: P1
# S = 63: P1
# S = 64: P1
# S = 65: P1
# S = 66: P1

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+1, b), (a, b+1), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 75:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'
    if all(game(m) in ['P1', 'P2'] for m in moves(h)):
        return 'V2'
    if any(game(m) in ['V1', 'V2'] for m in moves(h)):
        return 'P3'
    if all(game(m) in ['P1', 'P2', 'P3'] for m in moves(h)):
        return 'V3'

for s in range(1, 66+1, 1):
    print('S = ' + str(s) + ': ' + str(game((8, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: None
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: P3
# S = 15: None
# S = 16: None
# S = 17: None
# S = 18: None
# S = 19: None
# S = 20: None
# S = 21: None
# S = 22: None
# S = 23: None
# S = 24: None
# S = 25: None
# S = 26: None
# S = 27: P3
# S = 28: V2
# S = 29: P2
# S = 30: V3
# S = 31: P3
# S = 32: P2
# S = 33: V1
# S = 34: P1
# S = 35: P1
# S = 36: P1
# S = 37: P1
# S = 38: P1
# S = 39: P1
# S = 40: P1
# S = 41: P1
# S = 42: P1
# S = 43: P1
# S = 44: P1
# S = 45: P1
# S = 46: P1
# S = 47: P1
# S = 48: P1
# S = 49: P1
# S = 50: P1
# S = 51: P1
# S = 52: P1
# S = 53: P1
# S = 54: P1
# S = 55: P1
# S = 56: P1
# S = 57: P1
# S = 58: P1
# S = 59: P1
# S = 60: P1
# S = 61: P1
# S = 62: P1
# S = 63: P1
# S = 64: P1
# S = 65: P1
# S = 66: P1

# %% [markdown]
# ## 11

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+2, b), (a, b+2), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 62:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if any(game(m) == 'P1' for m in moves(h)):
        return 'V1'

for s in range(1, 54+1, 1):
    print('S = ' + str(s) + ': ' + str(game((7, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: None
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: V1
# S = 15: V1
# S = 16: V1
# S = 17: V1
# S = 18: V1
# S = 19: V1
# S = 20: V1
# S = 21: V1
# S = 22: V1
# S = 23: V1
# S = 24: V1
# S = 25: V1
# S = 26: V1
# S = 27: V1
# S = 28: P1
# S = 29: P1
# S = 30: P1
# S = 31: P1
# S = 32: P1
# S = 33: P1
# S = 34: P1
# S = 35: P1
# S = 36: P1
# S = 37: P1
# S = 38: P1
# S = 39: P1
# S = 40: P1
# S = 41: P1
# S = 42: P1
# S = 43: P1
# S = 44: P1
# S = 45: P1
# S = 46: P1
# S = 47: P1
# S = 48: P1
# S = 49: P1
# S = 50: P1
# S = 51: P1
# S = 52: P1
# S = 53: P1
# S = 54: P1

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+2, b), (a, b+2), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 62:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'

for s in range(1, 54+1, 1):
    print('S = ' + str(s) + ': ' + str(game((7, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: None
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: None
# S = 15: None
# S = 16: None
# S = 17: None
# S = 18: None
# S = 19: None
# S = 20: None
# S = 21: None
# S = 22: None
# S = 23: P2
# S = 24: None
# S = 25: P2
# S = 26: P2
# S = 27: V1
# S = 28: P1
# S = 29: P1
# S = 30: P1
# S = 31: P1
# S = 32: P1
# S = 33: P1
# S = 34: P1
# S = 35: P1
# S = 36: P1
# S = 37: P1
# S = 38: P1
# S = 39: P1
# S = 40: P1
# S = 41: P1
# S = 42: P1
# S = 43: P1
# S = 44: P1
# S = 45: P1
# S = 46: P1
# S = 47: P1
# S = 48: P1
# S = 49: P1
# S = 50: P1
# S = 51: P1
# S = 52: P1
# S = 53: P1
# S = 54: P1

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+2, b), (a, b+2), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 62:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'
    if all(game(m) in ['P1', 'P2'] for m in moves(h)):
        return 'V2'

for s in range(1, 54+1, 1):
    print('S = ' + str(s) + ': ' + str(game((7, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: None
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: None
# S = 15: None
# S = 16: None
# S = 17: None
# S = 18: None
# S = 19: None
# S = 20: None
# S = 21: V2
# S = 22: None
# S = 23: P2
# S = 24: V2
# S = 25: P2
# S = 26: P2
# S = 27: V1
# S = 28: P1
# S = 29: P1
# S = 30: P1
# S = 31: P1
# S = 32: P1
# S = 33: P1
# S = 34: P1
# S = 35: P1
# S = 36: P1
# S = 37: P1
# S = 38: P1
# S = 39: P1
# S = 40: P1
# S = 41: P1
# S = 42: P1
# S = 43: P1
# S = 44: P1
# S = 45: P1
# S = 46: P1
# S = 47: P1
# S = 48: P1
# S = 49: P1
# S = 50: P1
# S = 51: P1
# S = 52: P1
# S = 53: P1
# S = 54: P1

# %% [markdown]
# ## 31

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+1, b), (a, b+1), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 41:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'
    if all(game(m) in ['P1', 'P2'] for m in moves(h)):
        return 'V2'

for s in range(1, 31+1, 1):
    print('S = ' + str(s) + ': ' + str(game((9, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: P2
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: V2
# S = 15: P2
# S = 16: P1
# S = 17: P1
# S = 18: P1
# S = 19: P1
# S = 20: P1
# S = 21: P1
# S = 22: P1
# S = 23: P1
# S = 24: P1
# S = 25: P1
# S = 26: P1
# S = 27: P1
# S = 28: P1
# S = 29: P1
# S = 30: P1
# S = 31: P1

# %% [markdown]
# ## 32

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+1, b), (a, b+1), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 40:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if any(game(m) == 'P1' for m in moves(h)):
        return 'V1'

for s in range(1, 30+1, 1):
    print('S = ' + str(s) + ': ' + str(game((9, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: V1
# S = 5: V1
# S = 6: V1
# S = 7: V1
# S = 8: V1
# S = 9: V1
# S = 10: V1
# S = 11: V1
# S = 12: V1
# S = 13: V1
# S = 14: V1
# S = 15: V1
# S = 16: P1
# S = 17: P1
# S = 18: P1
# S = 19: P1
# S = 20: P1
# S = 21: P1
# S = 22: P1
# S = 23: P1
# S = 24: P1
# S = 25: P1
# S = 26: P1
# S = 27: P1
# S = 28: P1
# S = 29: P1
# S = 30: P1

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+1, b), (a, b+1), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 40:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'
    if all(game(m) in ['P1', 'P2'] for m in moves(h)):
        return 'V2'

for s in range(1, 30+1, 1):
    print('S = ' + str(s) + ': ' + str(game((9, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: P2
# S = 4: None
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: P2
# S = 15: V1
# S = 16: P1
# S = 17: P1
# S = 18: P1
# S = 19: P1
# S = 20: P1
# S = 21: P1
# S = 22: P1
# S = 23: P1
# S = 24: P1
# S = 25: P1
# S = 26: P1
# S = 27: P1
# S = 28: P1
# S = 29: P1
# S = 30: P1

# %%
from functools import lru_cache

def moves(h):
    a, b = h
    return (a+1, b), (a, b+1), (a*2, b), (a, b*2)

@lru_cache(None)
def game(h):
    if sum(h) >= 41:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'
    if all(game(m) in ['P1', 'P2'] for m in moves(h)):
        return 'V2'

for s in range(1, 31+1, 1):
    print('S = ' + str(s) + ': ' + str(game((9, s))))
# Out:
# S = 1: None
# S = 2: None
# S = 3: None
# S = 4: P2
# S = 5: None
# S = 6: None
# S = 7: None
# S = 8: None
# S = 9: None
# S = 10: None
# S = 11: None
# S = 12: None
# S = 13: None
# S = 14: V2
# S = 15: P2
# S = 16: P1
# S = 17: P1
# S = 18: P1
# S = 19: P1
# S = 20: P1
# S = 21: P1
# S = 22: P1
# S = 23: P1
# S = 24: P1
# S = 25: P1
# S = 26: P1
# S = 27: P1
# S = 28: P1
# S = 29: P1
# S = 30: P1
# S = 31: P1

# %% [markdown]
# ## 85

# %%
from functools import lru_cache

def moves(h):
    x1 = h - 2
    if h % 2 == 0:
        x1 = h // 2

    x2 = h - 3
    if h % 3 == 0:
        x2 = h // 3

    return x1, x2

@lru_cache(None)
def game(h):
    if h == 1:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if any(game(m) == 'P1' for m in moves(h)):
        return 'V1'

for s in range(2, 37+1, 1):
    print('S = ' + str(s) + ': ' + str(game(s)))
# Out:
# S = 2: P1
# S = 3: P1
# S = 4: P1
# S = 5: V1
# S = 6: V1
# S = 7: V1
# S = 8: V1
# S = 9: V1
# S = 10: None
# S = 11: None
# S = 12: V1
# S = 13: None
# S = 14: None
# S = 15: None
# S = 16: None
# S = 17: None
# S = 18: None
# S = 19: None
# S = 20: None
# S = 21: None
# S = 22: None
# S = 23: None
# S = 24: None
# S = 25: None
# S = 26: None
# S = 27: None
# S = 28: None
# S = 29: None
# S = 30: None
# S = 31: None
# S = 32: None
# S = 33: None
# S = 34: None
# S = 35: None
# S = 36: None
# S = 37: None

# %%
from functools import lru_cache

def moves(h):
    x1 = h - 2
    if h % 2 == 0:
        x1 = h // 2

    x2 = h - 3
    if h % 3 == 0:
        x2 = h // 3

    return x1, x2

@lru_cache(None)
def game(h):
    if h == 1:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'

for s in range(2, 37+1, 1):
    print('S = ' + str(s) + ': ' + str(game(s)))
# Out:
# S = 2: P1
# S = 3: P1
# S = 4: P1
# S = 5: V1
# S = 6: V1
# S = 7: P2
# S = 8: P2
# S = 9: None
# S = 10: P2
# S = 11: None
# S = 12: P2
# S = 13: None
# S = 14: None
# S = 15: P2
# S = 16: None
# S = 17: None
# S = 18: P2
# S = 19: None
# S = 20: None
# S = 21: None
# S = 22: None
# S = 23: None
# S = 24: None
# S = 25: None
# S = 26: None
# S = 27: None
# S = 28: None
# S = 29: None
# S = 30: None
# S = 31: None
# S = 32: None
# S = 33: None
# S = 34: None
# S = 35: None
# S = 36: None
# S = 37: None

# %%
from functools import lru_cache

def moves(h):
    x1 = h - 2
    if h % 2 == 0:
        x1 = h // 2

    x2 = h - 3
    if h % 3 == 0:
        x2 = h // 3

    return x1, x2

@lru_cache(None)
def game(h):
    if h == 1:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if all(game(m) == 'P1' for m in moves(h)):
        return 'V1'
    if any(game(m) == 'V1' for m in moves(h)):
        return 'P2'
    if any(game(m) in ['P1', 'P2'] for m in moves(h)):
        return 'V2'

for s in range(2, 37+1, 1):
    print('S = ' + str(s) + ': ' + str(game(s)))
# Out:
# S = 2: P1
# S = 3: P1
# S = 4: P1
# S = 5: V1
# S = 6: V1
# S = 7: P2
# S = 8: P2
# S = 9: V2
# S = 10: P2
# S = 11: V2
# S = 12: P2
# S = 13: V2
# S = 14: V2
# S = 15: P2
# S = 16: V2
# S = 17: V2
# S = 18: P2
# S = 19: None
# S = 20: V2
# S = 21: V2
# S = 22: None
# S = 23: None
# S = 24: V2
# S = 25: None
# S = 26: None
# S = 27: None
# S = 28: None
# S = 29: None
# S = 30: V2
# S = 31: None
# S = 32: None
# S = 33: None
# S = 34: None
# S = 35: None
# S = 36: V2
# S = 37: None

# %% [markdown]
# # reshuege 27802

# %%
from functools import lru_cache

def moves(h):
    return h+1, h+4, h*5

@lru_cache(None)
def game(h):
    if h >= 68:
        return 'W'
    if any(game(m) == 'W' for m in moves(h)):
        return 'P1'
    if any(game(m) == 'P1' for m in moves(h)):
        return 'V1'

for s in range(1, 67+1, 1):
    print('S = ' + str(s) + ': ' + str(game(s)))
# Out:
# S = 1: None
# S = 2: None
# S = 3: V1
# S = 4: V1
# S = 5: V1
# S = 6: V1
# S = 7: V1
# S = 8: V1
# S = 9: V1
# S = 10: V1
# S = 11: V1
# S = 12: V1
# S = 13: V1
# S = 14: P1
# S = 15: P1
# S = 16: P1
# S = 17: P1
# S = 18: P1
# S = 19: P1
# S = 20: P1
# S = 21: P1
# S = 22: P1
# S = 23: P1
# S = 24: P1
# S = 25: P1
# S = 26: P1
# S = 27: P1
# S = 28: P1
# S = 29: P1
# S = 30: P1
# S = 31: P1
# S = 32: P1
# S = 33: P1
# S = 34: P1
# S = 35: P1
# S = 36: P1
# S = 37: P1
# S = 38: P1
# S = 39: P1
# S = 40: P1
# S = 41: P1
# S = 42: P1
# S = 43: P1
# S = 44: P1
# S = 45: P1
# S = 46: P1
# S = 47: P1
# S = 48: P1
# S = 49: P1
# S = 50: P1
# S = 51: P1
# S = 52: P1
# S = 53: P1
# S = 54: P1
# S = 55: P1
# S = 56: P1
# S = 57: P1
# S = 58: P1
# S = 59: P1
# S = 60: P1
# S = 61: P1
# S = 62: P1
# S = 63: P1
# S = 64: P1
# S = 65: P1
# S = 66: P1
# S = 67: P1

# %% [markdown]
# ## Проверка решений

# %%
import pandas as pd
answers = pd.read_csv('answers.csv', encoding='windows-1251')[['19', '20', '21']]
# первая строчка ответов содержит какую-то ссылку на YouTube
answers.iloc[0][0] = '17'
answers.iloc[0][1] = '29 32'
answers.iloc[0][2] = '28'

# solutions = [None] * (len(answers)+1) # solutions[i] - решение i-й задачи. solutions[0] не используется.

# %%
ok_flag = True

solutions = [str(solution) if solution != None else None for solution in solutions]
solved = []

for i in range(1, len(answers)):
    if solutions[i] is not None:
        if solutions[i] == answers[i]:
            solved.append(i)
        else:
            print('Error in problem {}. Correct Answer: {}. Given: {}'.format(i, answers[i], solutions[i]))
            ok_flag = False

if ok_flag:
    print('OK!')
print('Solved problems: {}'.format(solved))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DMITRY~1\AppData\Local\Temp/ipykernel_12964/1354734768.py in <module>
#       1 ok_flag = True
#       2
# ----> 3 solutions = [str(solution) if solution != None else None for solution in solutions]
#       4 solved = []
#       5
#
# NameError: name 'solutions' is not defined
